# %%
import re # for regular expression
import sys
import nltk

# %%
#用utf-8-sig解決出現\ufeff
with open ('./Chapter/Chapter1.txt', 'r', encoding = 'utf-8-sig') as inFile:
    Lines = inFile.readlines()

# %%
Symbols = [ '•', '○', '●', '◎', '↑', '↓', '←', '→', '->', '<-', '`']
Del = ['FIGURE','Chapter 1','1.1','1.2','1.3','1.4','1.5','1.6','1.7']
for lid in range(len(Lines)):
    Lines[lid] = Lines[lid].replace('\n', '').strip()
    for s in Symbols:
        Lines[lid] = Lines[lid].replace(s, '').strip()
    for d in Del:
        if d in Lines[lid]:
            Lines[lid]='.'

# %%
Lines
# Out:
# ['After reading this chapter, you will be able to 1. Discuss the goal of a supply chain and explain the impact of supply chain decisions on the success of a firm. 2. Identify the three key supply chain decision phases and explain the significance of each one. 3. Describe the cycle and push/pull views of a supply chain. 4. Classify the supply chain macro processes in a firm.',
#  '',
#  'In this chapter, we provide a conceptual understanding of what a supply chain is and the various issues that need to be considered when designing, planning, or operating a supply chain. We discuss the significance of supply chain decisions and supply chain performance for the success of a firm. We also provide several examples from different industries to emphasize the variety of supply chain issues that companies need to consider at the strategic, planning, and operational levels.',
#  '.',
# ...

# %%
senTokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
SentenceList = []
all =' '.join(str(d) for d in Lines)
seg=nltk.sent_tokenize(all)

# %%
for sid in range(len(seg)):
    if len(seg[sid])<=20:
        print(seg[sid])
        seg[sid]=''
while '' in seg:
    seg.remove('')
# Out:
# 2.
# 3.
# 4.
# .
# 1  .
# .
# .
# .
# .
# .
# 1.
# 2.
# 3.
# .
# .
# 1.
# 2.
# .
# .
# of customer demand.
# .
# .
# 2.
# 3.
# 4.
# 5.
# 2.
# 3.
# 4.
# 5.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.
# 2.
# 3.
# 4.
# 5.
# 6.
# It uses the U.S.
# 2.
# 3.
# 4.
# .
# 5.
# 6.
# .
# 1.
# 2.
# 3.
# 4.
# 2.
# 3.
# 4.
# 5.
# 6.

# %%
with open ('Chapter1_after.txt', 'w', encoding = 'utf-8') as outFile:
    for line in seg:
        r='Discussion Questions' in line
        if r == True:
            break;
            print("yes")
        else:
            outFile.write(line + '\n')
#         if line in 'Discussion Questions':
#             break;

# %%
seg[5]
# Out:
# 'In this chapter, we provide a conceptual understanding of what a supply chain is and the various issues that need to be considered when designing, planning, or operating a supply chain.'
